# %%
from TRTengine_yolov8 import *
import streamlit

# %%
cap = cv2.VideoCapture("/home/airi/yolo/Yolov5_Video_Inference/supermodel.mp4")
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Initialize the VideoWriter
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # or use 'XVID'
out = cv2.VideoWriter('output.mp4', fourcc, 20.0, (width, height))

fps = 0
fpss = []
prev_time = 0
curr_time = 0
while True:
    ret, frame = cap.read()
    if not ret:
        break
    frame = cv2.resize(frame, (width, height))
    
    prev_time = time.time()
    output_img = run_tensorrt(enggine_path = "/home/airi/yolo/Yolov5_Video_Inference/Models/fp16.engine", image = frame)
    curr_time = time.time()
    #Write the frame into the file 'output.mp4'
    out.write(output_img)

    cv2.putText(output_img, f'FPS:{fps:.3f}', 
                (10, 30),  # Position of the text
                cv2.FONT_HERSHEY_SIMPLEX,
                0.75, 
                (0, 255, 0),  # Color in BGR format (green in this case)
                thickness=2)
    cv2.imwrite(f"/home/airi/yolo/Yolov5_Video_Inference/streamlit/images/next.png", output_img)
    
    fps = (1 / (curr_time - prev_time))
    print("FPS: --", fps)
    fpss.append(fps)
plt.plot(fpss)
plt.savefig('MyPlot.png')

# Release everything after the job is finished
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# [09/06/2023-14:17:19] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:19] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:19] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 5.157738629572335
# [09/06/2023-14:17:19] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:19] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:20] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.568265705771167
# [09/06/2023-14:17:20] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:20] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:20] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.7885254073791135
# [09/06/2023-14:17:20] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:20] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:20] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.805278332584277
# [09/06/2023-14:17:20] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:20] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:20] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.810460785046001
# [09/06/2023-14:17:20] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:20] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:20] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.836770487634721
# [09/06/2023-14:17:20] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:20] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:20] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.802519052646773
# [09/06/2023-14:17:21] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:21] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:21] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.830936001667709
# [09/06/2023-14:17:21] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:21] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:21] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.776581289654426
# [09/06/2023-14:17:21] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:21] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:21] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.817623107368968
# [09/06/2023-14:17:21] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:21] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:21] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.818276989901748
# [09/06/2023-14:17:21] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:21] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:21] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.820017593524542
# [09/06/2023-14:17:22] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:22] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:22] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.837940810613854
# [09/06/2023-14:17:22] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:22] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:22] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.826255580311733
# [09/06/2023-14:17:22] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:22] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:22] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.835355489318291
# [09/06/2023-14:17:22] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:22] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:22] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.825888977492799
# [09/06/2023-14:17:22] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:22] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:22] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.794672870095725
# [09/06/2023-14:17:23] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:23] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:23] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.8390334736152125
# [09/06/2023-14:17:23] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:23] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:23] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.820749577596258
# [09/06/2023-14:17:23] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:23] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:23] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.84243634417864
# [09/06/2023-14:17:23] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:23] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:23] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.8276223559938405
# [09/06/2023-14:17:23] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:23] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:23] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.816470806199711
# [09/06/2023-14:17:23] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:24] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:24] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.796797925781883
# [09/06/2023-14:17:24] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:24] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:24] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.80207777548932
# [09/06/2023-14:17:24] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:24] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:24] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.814842737048026
# [09/06/2023-14:17:24] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:24] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:24] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.826166703285079
# [09/06/2023-14:17:24] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:24] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:24] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.826322239600541
# [09/06/2023-14:17:24] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:25] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:25] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.820095220750839
# [09/06/2023-14:17:25] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:25] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:25] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.807564710999734
# [09/06/2023-14:17:25] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:25] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:25] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.7181419933528215
# [09/06/2023-14:17:25] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:25] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:25] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.786174939245971
# [09/06/2023-14:17:25] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:25] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:25] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.788558369439782
# [09/06/2023-14:17:25] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:25] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:25] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.793968481769867
# [09/06/2023-14:17:26] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:26] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:26] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.784857631845432
# [09/06/2023-14:17:26] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:26] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:26] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.758694702850081
# [09/06/2023-14:17:26] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:26] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:26] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.784649105070325
# [09/06/2023-14:17:26] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:26] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:26] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.7833653015742605
# [09/06/2023-14:17:26] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:26] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:26] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.8099521357085795
# [09/06/2023-14:17:27] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:27] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:27] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.7542867449080815
# [09/06/2023-14:17:27] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:27] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:27] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.746464555479778
# [09/06/2023-14:17:27] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:27] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:27] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.737253314571909
# [09/06/2023-14:17:27] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:27] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:27] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.737945991100259
# [09/06/2023-14:17:27] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:27] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:27] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.709265441469341
# [09/06/2023-14:17:28] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:28] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:28] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.763184755074037
# [09/06/2023-14:17:28] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:28] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:28] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.758607576375271
# [09/06/2023-14:17:28] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:28] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:28] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.763042987519753
# [09/06/2023-14:17:28] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:28] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:28] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.746844381817334
# [09/06/2023-14:17:28] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:28] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:28] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.7896462970457305
# [09/06/2023-14:17:29] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:29] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:29] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.771745430533289
# [09/06/2023-14:17:29] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:29] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:29] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.765311981831437
# [09/06/2023-14:17:29] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:29] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# [09/06/2023-14:17:29] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# FPS: -- 6.762007174237233
# [09/06/2023-14:17:29] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [09/06/2023-14:17:29] [TRT] [W] TensorRT was linked against cuDNN 8.9.0 but loaded cuDNN 8.5.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 20
#      17 frame = cv2.resize(frame, (width, height))
#      19 prev_time = time.time()
# ---> 20 output_img = run_tensorrt(enggine_path = "/home/airi/yolo/Yolov5_Video_Inference/Models/fp16.engine", image = frame)
#      21 curr_time = time.time()
#      22 #Write the frame into the file 'output.mp4'
#
# File ~/yolo/Yolov5_Video_Inference/streamlit/TRTengine_yolov8.py:201, in run_tensorrt(enggine_path, image)
#     199 def run_tensorrt(enggine_path, image):
# --> 201     enggine = TRTEngine(enggine_path)
#     203     H, W = enggine.inp_info[0].shape[-2:]
#     205     # image = cv2.imread(image_path)
#
# File ~/yolo/Yolov5_Video_Inference/streamlit/TRTengine_yolov8.py:22, in TRTEngine.__init__(self, weight)
#      20 self.weight = Path(weight) if isinstance(weight, str) else weight
#      21 self.stream = cuda.Stream(0)
# ---> 22 self.__init_engine()
#      23 self.__init_bindings()
#      24 self.__warm_up()
#
# File ~/yolo/Yolov5_Video_Inference/streamlit/TRTengine_yolov8.py:30, in TRTEngine.__init_engine(self)
#      28 trt.init_libnvinfer_plugins(logger, namespace='')
#      29 with trt.Runtime(logger) as runtime:
# ---> 30     model = runtime.deserialize_cuda_engine(self.weight.read_bytes())
#      32 context = model.create_execution_context()
#      34 names = [model.get_binding_name(i) for i in range(model.num_bindings)]
#
# KeyboardInterrupt:

# %%
! streamlit run stream.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://192.169.0.146:8503
#   External URL: http://195.158.1.149:8503
#
# ^C
#   Stopping...
